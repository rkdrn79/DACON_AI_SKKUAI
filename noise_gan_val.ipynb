# %%
import warnings
warnings.filterwarnings("ignore")
import librosa

# %%
from diffusers import AudioLDM2Pipeline
import torch

repo_id = "cvssp/audioldm2"
pipe = AudioLDM2Pipeline.from_pretrained(repo_id, torch_dtype=torch.float16, sr = 16000)
pipe = pipe.to("cuda:0")
# Out:
# Keyword arguments {'sr': 16000} are not expected by AudioLDM2Pipeline and will be ignored.
# Loading pipeline components...:   0%|          | 0/11 [00:00<?, ?it/s]

# %%
"""
prompts = [
    ["Birdsong at dawn in the forest", "Melodious birdsong at sunrise in a pine forest"],
    ["Gentle stream flowing over rocks", "Babbling brook cascading over mossy rocks"],
    ["Wind rustling through the leaves", "Strong breeze rustling autumn leaves"],
    ["Ocean waves crashing on the shore", "Powerful ocean waves crashing on a rocky beach"],
    ["Rain falling on a tin roof", "Heavy rain drumming on an old tin roof"],
    ["Thunderstorm with distant thunder", "Intense thunderstorm with rolling thunder nearby"],
    ["Crickets chirping on a summer night", "Chorus of crickets chirping on a warm, moonlit night"],
    ["Frogs croaking by a pond", "Bullfrogs croaking loudly around a lily-covered pond"],
    ["Bees buzzing around flowers", "Swarm of honeybees buzzing around a colorful flower garden"],
    ["Leaves crunching underfoot", "Dry autumn leaves crunching under hiking boots"],
    ["Woodpecker tapping on a tree", "Pileated woodpecker rapidly tapping on a hollow oak tree"],
    ["Owls hooting at night", "Pair of great horned owls hooting in a misty forest at midnight"],
    ["Wolves howling in the distance", "Pack of gray wolves howling at a full moon from a distant ridge"],
    ["Campfire crackling in the woods", "Roaring campfire crackling and popping in a dense pine forest"],
    ["Eagles screeching in the mountains", "Bald eagles screeching while soaring over snow-capped mountain peaks"],
    ["Snow falling in a quiet forest", "Soft snowflakes gently falling in a hushed, moonlit forest"],
    ["Mountain stream trickling down rocks", "Icy mountain stream trickling down jagged granite rocks"],
    ["Geese honking during migration", "Flock of Canada geese honking loudly during autumn migration"],
    ["Waterfall roaring in a canyon", "Massive waterfall thunderously roaring in a deep, echoing canyon"],
    ["Hail hitting a glass window", "Large hailstones forcefully pelting a bay window during a storm"],
    ["Distant train horn in the countryside", "Mournful train horn echoing across misty rural fields at dawn"],
    ["Cicadas singing on a hot day", "Deafening chorus of cicadas singing on a scorching summer afternoon"],
    ["Horses trotting on a dirt road", "Team of draft horses trotting rhythmically on a dusty country road"],
    ["Ducks quacking on a lake", "Flock of mallard ducks quacking excitedly on a serene lake at sunset"],
    ["Seagulls calling at the beach", "Flock of seagulls squawking and calling over a crowded beach"],
    ["Dogs barking in a neighborhood", "Various breeds of dogs barking in a bustling suburban neighborhood"],
    ["Cats meowing in an alley", "Stray cats yowling and meowing in a narrow city alley at night"],
    ["Children laughing in a playground", "Group of excited children laughing and shouting in a busy playground"],
    ["Bicycles whizzing by on a street", "Racing bicycles whizzing by on a steep downhill street"],
    ["Traffic humming on a busy highway", "Heavy traffic humming and honking on a congested six-lane highway"],
    ["Car horns honking in the city", "Cacophony of car horns honking impatiently in rush hour city traffic"],
    ["People chatting in a cafe", "Lively chatter of people in a bustling cafe during lunch hour"],
    ["Footsteps echoing in a hallway", "Solitary footsteps echoing in a long, empty marble hallway"],
    ["Elevator doors opening and closing", "Old elevator doors creaking open and slamming shut"],
    ["Keyboard typing in an office", "Rapid keyboard typing in a quiet, open-plan office"],
    ["Phone ringing in an office", "Landline phone persistently ringing in a busy corporate office"],
    ["Construction site noises in the city", "Loud construction site with jackhammers and cranes in a dense urban area"],
    ["Helicopter flying overhead", "Military helicopter flying low overhead with rotor blades thumping"],
    ["Airplane taking off from a runway", "Jumbo jet engines roaring as the plane takes off from the runway"],
    ["Train rumbling down the tracks", "High-speed train rumbling and whistling as it races down the tracks"],
    ["Subway arriving at a station", "Screeching subway train arriving at a crowded underground station"],
    ["Bus brakes squealing at a stop", "City bus air brakes hissing and squealing as it stops at a busy corner"],
    ["Ambulance siren in the distance", "Wailing ambulance siren growing louder as it approaches through city streets"],
    ["Police siren passing by", "Police car siren blaring as it speeds past with lights flashing"],
    ["Fire truck siren on the move", "Fire truck siren wailing urgently as it rushes to an emergency"],
    ["Marketplace hustle and bustle", "Vibrant outdoor marketplace with vendors shouting and crowds haggling"],
    ["Fountain splashing in a park", "Ornate fountain splashing and gurgling in a tranquil city park"],
    ["Church bells ringing", "Majestic church bells pealing from a tall cathedral tower at noon"],
    ["Street musicians playing guitar", "Skilled street musicians playing flamenco guitar in a lively town square"],
    ["Ice cream truck jingle in the neighborhood", "Cheerful ice cream truck jingle echoing through a suburban neighborhood"],
    ["Garbage truck collecting trash", "Noisy garbage truck hydraulics as it collects and compacts trash"],
    ["Snowplow clearing the road", "Heavy snowplow scraping and rumbling as it clears a snowy mountain road"],
    ["Leaves blowing in the wind", "Dry leaves skittering and swirling in gusts of autumn wind"],
    ["Flags flapping in the breeze", "Large flags snapping and flapping in a strong coastal breeze"],
    ["Boat motor on a lake", "Outboard boat motor puttering across a misty lake at dawn"],
    ["Kayakers paddling in a river", "Kayakers vigorously paddling through swift river rapids"],
    ["Fishermen casting lines", "Fishermen repeatedly casting lines into a calm river at sunrise"],
    ["Golfers swinging clubs", "Golfers swinging clubs and hitting balls on a manicured course"],
    ["Tennis ball bouncing on a court", "Tennis ball rapidly bouncing and rackets swinging during an intense match"],
    ["Soccer game cheers from a stadium", "Roaring cheers and chants from a packed soccer stadium after a goal"],
    ["Basketball game sounds in a gym", "Squeaking sneakers and bouncing balls during a lively basketball game"],
    ["Baseball game with bat hitting ball", "Crack of a baseball bat hitting a fastball in a major league game"],
    ["Hockey game with puck hitting stick", "Hockey puck slapping against sticks and boards in an intense game"],
    ["Skateboard wheels on pavement", "Skateboard wheels rolling and clacking over rough pavement"],
    ["Roller coaster screams at an amusement park", "Thrilling screams from riders on a looping roller coaster"],
    ["Ferris wheel creaking", "Giant Ferris wheel slowly creaking and groaning as it rotates"],
    ["Water slide splashes", "Excited shrieks and splashes from riders on a twisting water slide"],
    ["Carnival games and rides", "Cacophony of carnival rides, games, and excited patrons"],
    ["Fireworks exploding in the sky", "Spectacular fireworks booming and crackling in the night sky"],
    ["Parade marching band", "Energetic marching band playing as they march down Main Street"],
    ["Street festival music and chatter", "Lively music and chatter from a crowded street food festival"],
    ["Picnic in the park with kids playing", "Joyful sounds of a family picnic with kids playing frisbee"],
    ["Wedding reception with clinking glasses", "Festive wedding reception with clinking glasses and laughter"],
    ["Birthday party with kids singing", "Excited kids singing 'Happy Birthday' off-key at a party"],
    ["Concert crowd cheering", "Massive concert crowd cheering and singing along with the band"],
    ["Jazz band playing in a club", "Smooth jazz band playing in a dimly lit, smoky club"],
    ["Opera singer hitting high notes", "Powerful opera singer hitting impressive high notes on stage"],
    ["Symphony orchestra tuning instruments", "Full symphony orchestra tuning their instruments before a performance"],
    ["Theater audience applauding", "Thunderous applause from a theater audience after a standing ovation"],
    ["Movie theater previews and popcorn", "Movie theater with previews playing and people munching popcorn"],
    ["Classroom with teacher and students", "Busy classroom with teacher lecturing and students discussing"],
    ["Library with pages turning", "Quiet library with occasional whispers and pages turning"],
    ["Museum with guided tour", "Museum guide explaining exhibits to an attentive tour group"],
    ["Art gallery with murmuring visitors", "Art gallery with visitors murmuring quietly about the paintings"],
    ["Zoo with animals and visitors", "Busy zoo with various animal sounds and excited visitors"],
    ["Aquarium with bubbling tanks", "Large aquarium with bubbling tanks and tapping on glass"],
    ["Farm with mooing cows", "Dairy farm with cows mooing and machinery humming"],
    ["Sheep bleating in a field", "Flock of sheep bleating as they graze in a hilly field"],
    ["Pigs oinking in a pen", "Group of pigs oinking and snorting in a muddy pen"],
    ["Chickens clucking in a coop", "Hen house full of chickens clucking and roosters crowing"],
    ["Rooster crowing at sunrise", "Loud rooster crowing to announce the sunrise on a farm"],
    ["Tractor working in a field", "Old tractor engine rumbling as it plows a large field"],
    ["Windmill creaking in the breeze", "Wooden windmill creaking as it turns in a steady breeze"],
    ["Farmer's market with vendors", "Bustling farmer's market with vendors calling out their produce"],
    ["Harvest festival with live music", "Lively harvest festival with folk music and dancing"],
    ["Apple orchard with picking", "Apple orchard with people picking fruit and laughing"],
    ["Vineyard with grape stomping", "Traditional vineyard with people stomping grapes"],
    ["Winery with wine tasting", "Elegant winery with people swirling and sipping wines"],
    ["Cider mill with pressing apples", "Cider mill with apples being crushed and pressed"],
    ["Pumpkin patch with children", "Cheerful pumpkin patch with children searching for the perfect pumpkin"],
    ["Haunted house with spooky sounds", "Eerie haunted house with ghostly moans and creaking doors"],
    ["Christmas market with carolers", "Festive Christmas market with carolers singing traditional songs"],
    ["New Year's Eve countdown", "Exciting New Year's Eve party with countdown and cheering"],
    ["Easter egg hunt with kids", "Joyful Easter egg hunt with children searching and giggling"],
    ["Fourth of July BBQ with fireworks", "Lively Fourth of July BBQ with conversation and distant fireworks"],
    ["Thanksgiving dinner chatter", "Warm Thanksgiving dinner with family chatting and laughing"],
    ["Halloween trick-or-treaters", "Halloween night with trick-or-treaters laughing and shouting"],
    ["Clinking of dishes in a busy kitchen", "Busy restaurant kitchen with dishes clinking and chefs shouting orders"],
    ["Whistling kettle on a stove", "Tea kettle whistling shrilly on a gas stove"],
    ["Coffee machine brewing", "Espresso machine hissing and gurgling as it brews coffee"],
    ["Microwave beeping", "Microwave humming and beeping as it finishes heating"],
    ["Toaster popping", "Toaster lever clicking and bread popping up when done"],
    ["Blender whirring", "Powerful blender whirring as it crushes ice and fruit"],
    ["Sizzling of food in a pan", "Food sizzling and popping in a hot frying pan"],
    ["Water boiling in a pot", "Water bubbling and boiling rapidly in a metal pot"],
    ["Fireplace roaring", "Cozy fireplace crackling and roaring on a cold night"],
    ["Dishwasher running", "Dishwasher whooshing and spraying as it cleans a full load"],
    ["Vacuum cleaner humming", "Vacuum cleaner motor humming as it moves across carpet"],
    ["Washing machine spinning", "Washing machine thumping and spinning during a heavy cycle"],
    ["Dryer tumbling", "Clothes dryer thumping and tumbling a load of laundry"],
    ["Shower running", "Shower water spraying and splashing in a tiled bathroom"],
    ["Hairdryer blowing", "Hairdryer blowing on high heat in an echoey bathroom"],
    ["Toilet flushing", "Toilet flushing with a rush of water in a quiet bathroom"],
    ["Sink faucet dripping", "Leaky sink faucet steadily dripping in the middle of the night"],
    ["Lawnmower cutting grass", "Gas-powered lawnmower loudly cutting thick grass"],
    ["Sprinklers watering lawn", "Oscillating sprinklers rhythmically watering a large lawn"],
    ["Birdbath splashing", "Birds splashing and chirping in a garden birdbath"],
    ["Wind chimes tinkling", "Delicate wind chimes tinkling in a gentle breeze"],
    ["Doorbell ringing", "Melodic doorbell chiming through a large house"],
    ["Garage door opening", "Electric garage door motor whirring as the door rises"],
    ["Mail truck stopping", "Mail truck engine idling and brakes squeaking as it stops"],
    ["Newspaper landing on a porch", "Thud of a rolled newspaper landing on a wooden porch"],
    ["Keys jingling", "Bundle of keys jingling as someone unlocks a door"],
    ["Car engine starting", "Car engine turning over and roaring to life"],
    ["Windshield wipers swishing", "Windshield wipers swishing back and forth in heavy rain"],
    ["Car tires on gravel", "Car tires crunching slowly over a gravel driveway"],
    ["Bicycle bell ringing", "Cheerful bicycle bell ringing on a busy bike path"],
    ["Rollerblades on pavement", "Rollerblades rhythmically gliding and clicking on smooth pavement"],
    ["Skateboard landing tricks", "Skateboard clacking as it lands after an ollie"],
    ["Scooter zipping by", "Electric scooter quietly zipping past on a sidewalk"],
    ["Motorcycle revving", "Motorcycle engine revving loudly at a stoplight"],
    ["Truck horn blaring", "Deep truck horn blaring on a busy highway"],
    ["Semi-truck driving by", "Semi-truck engine rumbling as it passes on the highway"],
    ["Snowblower clearing driveway", "Snowblower engine roaring as it clears a long driveway"],
    ["Ice skates on a rink", "Ice skates scraping and gliding across a smooth rink"],
    ["Skiers going down a slope", "Skis swishing down a steep, snowy slope"],
    ["Snowshoes crunching snow", "Snowshoes crunching through deep, powdery snow"],
    ["Firewood being chopped", "Axe rhythmically chopping firewood on a chopping block"],
    ["Rake gathering leaves", "Metal rake scraping as it gathers piles of dry leaves"],
    ["Shovel digging soil", "Shovel repeatedly digging and turning over soil in a garden"],
    ["Garden hose spraying water", "Garden hose spraying water on flowers and shrubs"],
    ["Bird feeder being filled", "Bird seed pouring into a metal bird feeder"],
    ["Compost bin being turned", "Compost bin creaking as it's turned and mixed"],
    ["Ladder being climbed", "Aluminum ladder creaking as someone climbs it"],
    ["Paintbrush on canvas", "Paintbrush softly scratching as it moves across a canvas"],
    ["Hammer hitting nail", "Hammer repeatedly striking nails into wood"],
    ["Saw cutting wood", "Electric circular saw loudly buzzing as it cuts through hardwood"],
    ["Drill drilling into wall", "Power drill whirring as it bores into a concrete wall"],
    ["Wrench turning bolt", "Metal wrench clanking as it tightens a large bolt"],
    ["Screwdriver tightening screw", "Manual screwdriver squeaking as it tightens a screw"],
    ["Tape measure retracting", "Metal tape measure zipping as it quickly retracts"],
    ["Level hitting surface", "Bubble level tapping against a wooden surface"],
    ["Glue gun gluing", "Hot glue gun clicking and oozing melted glue"],
    ["Stapler stapling paper", "Office stapler crunching as it binds papers together"],
    ["Scissors cutting paper", "Sharp scissors slicing through thick paper"],
    ["Paper being torn", "Sheet of paper slowly ripping along a straight edge"],
    ["Notebook pages turning", "Textbook pages rustling as they're quickly flipped"],
    ["Pen writing on paper", "Ballpoint pen scratching as it writes on rough paper"],
    ["Pencil sharpener", "Electric pencil sharpener grinding a pencil to a point"],
    ["Marker cap clicking", "Dry-erase marker cap clicking as it's removed and replaced"],
    ["Eraser erasing pencil marks", "Rubber eraser vigorously rubbing away pencil marks"],
    ["Sticky notes being peeled", "Sticky note adhesive sound as it's peeled from a pad"],
    ["Book being closed", "Hardcover book thudding shut after reading"],
    ["Magazine pages flipping", "Glossy magazine pages rapidly flipping"],
    ["Newspaper being folded", "Large newspaper crinkling as it's folded for reading"],
    ["Envelope being sealed", "Envelope flap being licked and pressed to seal"],
    ["Stamps being applied", "Postage stamps peeling and sticking to envelopes"],
    ["Package being taped", "Packing tape loudly unrolling and being applied to a box"],
    ["Scotch tape dispenser", "Scotch tape squeaking as it's pulled from a desktop dispenser"],
    ["Packing peanuts rustling", "Styrofoam packing peanuts rustling in a shipping box"],
    ["Bubble wrap popping", "Bubble wrap crackling and popping as it's squeezed"],
    ["Chair scraping floor", "Wooden chair legs scraping across a tile floor"],
    ["Drawer opening", "Wooden drawer sliding open with a soft rumble"],
    ["Cabinet door closing", "Kitchen cabinet door quietly thumping shut"],
    ["Light switch clicking", "Light switch clicking on and off in a quiet room"],
    ["Curtains being drawn", "Heavy curtains sliding along a metal rod"],
    ["Blinds being adjusted", "Venetian blinds rattling as they're raised and lowered"],
    ["Fan blades spinning", "Ceiling fan blades whirring on high speed"],
    ["Air conditioning humming", "Central air conditioning unit humming as it runs"],
    ["Heater turning on", "Furnace roaring to life as the heater kicks on"],
    ["Alarm clock beeping", "Digital alarm clock beeping loudly to wake someone"],
    ["Phone vibrating", "Smartphone buzzing as it vibrates on a wooden table"],
    ["Text message notification", "Short ping of a text message arriving on a phone"],
    ["Email notification ping", "Gentle chime of an email notification on a computer"],
    ["Calendar reminder alert", "Soft bell sound of a calendar event reminder"],
    ["Electric toothbrush buzzing", "Electric toothbrush vibrating during use"],
    ["Razor shaving", "Electric razor buzzing as it shaves facial hair"],
    ["Nail clippers clipping", "Metal nail clippers snipping through fingernails"],
    ["Perfume spray", "Fine mist sound of perfume being sprayed"],
    ["Zipper closing", "Zipper teeth meshing as a jacket is zipped up"],
    ["Button being buttoned", "Small snap of a button being fastened"],
    ["Shoelaces being tied", "Shoelaces sliding and tightening as shoes are tied"],
    ["Clothes hanger on rack", "Metal clothes hanger scraping along a closet rod"],
    ["Closet door sliding", "Closet door rolling smoothly along its track"],
    ["Iron steaming clothes", "Steam iron hissing as it presses wrinkled fabric"],
    ["Lint roller rolling", "Adhesive lint roller peeling away fuzz from clothing"],
    ["Umbrella opening", "Umbrella whooshing open with a spring mechanism"],
    ["Raincoat rustling", "Waterproof raincoat material swishing with movement"]
]
"""
# Out:
# '\nprompts = [\n    ["Birdsong at dawn in the forest", "Melodious birdsong at sunrise in a pine forest"],\n    ["Gentle stream flowing over rocks", "Babbling brook cascading over mossy rocks"],\n    ["Wind rustling through the leaves", "Strong breeze rustling autumn leaves"],\n    ["Ocean waves crashing on the shore", "Powerful ocean waves crashing on a rocky beach"],\n    ["Rain falling on a tin roof", "Heavy rain drumming on an old tin roof"],\n    ["Thunderstorm with distant thunder", "Intense thunderstorm with rolling thunder nearby"],\n    ["Crickets chirping on a summer night", "Chorus of crickets chirping on a warm, moonlit night"],\n    ["Frogs croaking by a pond", "Bullfrogs croaking loudly around a lily-covered pond"],\n    ["Bees buzzing around flowers", "Swarm of honeybees buzzing around a colorful flower garden"],\n    ["Leaves crunching underfoot", "Dry autumn leaves crunching under hiking boots"],\n    ["Woodpecker tapping on a tree", "Pileated woodpecker rapidly tappi
# ...

# %%
prompts = [
    ["Pig Grunting in a Farmyard", "Pig grunting while searching for food in a muddy farmyard"],
    ["Cow Mooing in a Field", "Cow mooing loudly across a sunny field"],
    ["Sheep Bleating on a Hill", "Sheep bleating gently on a windy hillside"],
    ["Insect Buzzing in a Garden", "Insects buzzing around blooming flowers in a summer garden"],
    ["Cat Meowing at Home", "Cat meowing softly while sitting on a sunny windowsill"],
    ["Dog Barking in a Backyard", "Dog barking alertly in a quiet suburban backyard"],
    ["Chicken Clucking in a Coop", "Chicken clucking busily as it pecks at grain in a coop"],
    ["Crow Cawing in a Forest", "Crow cawing ominously from the top of a tall pine in a dense forest"],
    ["Bird Singing in the Morning", "Bird chirping melodiously at sunrise in a lush garden"],
    ["Duck Quacking by a Pond", "Duck quacking loudly near the reeds of a quiet pond"],
    ["Frog Croaking at Night", "Frog croaking rhythmically on a lily pad during a humid night"],
    ["Horse Neighing in a Stable", "Horse neighing warmly as it greets its owner in a stable"],
    ["Goat Bleating in a Barn", "Goat bleating curiously as it explores around a barn"],
    ["Owl Hooting in the Woods", "Owl hooting deeply from the shadows of a moonlit forest"],
    ["Elephant Trumpeting in the Savannah", "Elephant trumpeting powerfully across the open savannah"],
    ["Toilet Flushing", "Sound of a toilet being flushed"],
    ["Water Running in Sink", "Sound of running water from a bathroom sink"],
    ["Shower Water Flowing", "Sound of water flowing in a shower"],
    ["Operating Hair Dryer", "Sound of a hair dryer in use"],
    ["Brushing Teeth", "Sound of a toothbrush scrubbing against teeth"],
    ["Pouring Water", "Sound of water being poured into a glass"],
    ["Eating Crunchy Food", "Sound of someone crunching on food"],
    ["Swallowing Water", "Sound of someone gulping water"],
    ["Opening Fridge", "Sound of a refrigerator door being opened"],
    ["Utensils Clattering", "Sound of utensils clinking against each other"],
    ["Typing on Keyboard", "Sound of fingers tapping on computer keyboard"],
    ["Mouse Clicking", "Sound of a computer mouse being clicked"],
    ["Turning Pages", "Sound of pages being flipped in a document"],
    ["Printer Working", "Sound of a printer ejecting paper"],
    ["Phone Ringing", "Sound of a telephone ringing in an office setting"],
    ["Car Horn Beeping", "Sound of a car horn honking loudly in traffic"],
    ["Police Siren Wailing", "Sound of a police car siren echoing in the streets"],
    ["Ambulance Siren Blaring", "Sound of an ambulance siren as it rushes to an emergency"],
    ["Car Driving", "Sound of a car engine running smoothly while driving on the highway"],
    ["Traffic Noise", "Sound of continuous traffic moving on a busy road"],
    ["Rain Falling", "Sound of raindrops hitting the ground during a shower"],
    ["Thunder Clap", "Sound of a loud thunder clap during a storm"],
    ["Wind Howling", "Sound of strong wind howling through the trees"],
    ["Snow Crunching", "Sound of footsteps crunching on freshly fallen snow"],
    ["Hail Bouncing", "Sound of hailstones bouncing off a metal roof"],
    ["Chainsaw Cutting", "Sound of a chainsaw slicing through wood"],
    ["Glass Breaking", "Sound of glass shattering after hitting the floor"],
    ["Clock Ticking", "Sound of a clock ticking steadily in a silent room"],
    ["Helicopter Flying", "Sound of a helicopter hovering overhead"],
    ["Vacuum Cleaner Running", "Sound of a vacuum cleaner moving across a carpet"],
    ["Applause", "Sound of people clapping at a performance"],
    ["Sawing Wood", "Sound of a handsaw sawing through a log"],
    ["Alarm Ringing", "Sound of an alarm clock waking up someone"],
    ["Bell Ringing", "Sound of a bell tolling in the distance"],
    ["Can Opening", "Sound of a soda can being opened"],
    ["Crunching Chips", "Sound of someone eating crispy chips"],
    ["Clanking Noise", "Sound of dishes clanking in a sink"],
    ["Hammering Nail", "Sound of a hammer driving a nail into wood"],
    ["Knocking on Door", "Sound of someone knocking on a wooden door"],
    ["Creaking Door", "Sound of an old door creaking open"],
    ["Typing on Keyboard", "Sound of fingers typing on a keyboard"],
    ["Printer Printing", "Sound of a printer printing a document"],
    ["Dishwasher Running", "Sound of a dishwasher operating"],
    ["Children Playing", "Sound of children laughing and playing outside"],
    ["Sneezing", "Sound of someone sneezing loudly"],
    ["Bicycle Bell Ringing", "Sound of a bicycle bell ringing"],
    ["Traffic Noise", "Sound of traffic moving on a busy street"],
    ["Train Whistle", "Sound of a train whistle as it approaches a station"],
    ["Basketball Bouncing", "Sound of a basketball bouncing on the court"],
    ["Water Dripping", "Sound of water dripping from a faucet"],
    ["Wind Chimes", "Sound of wind chimes in a gentle breeze"],
    ["Leaf Blower", "Sound of a leaf blower cleaning a driveway"],
    ["Garage Door Opening", "Sound of a garage door opening"],
    ["Fire Crackling", "Sound of fire crackling in a fireplace"],
    ["Airplane Taking Off", "Sound of an airplane taking off in the distance"],
    ["Footsteps on Pavement", "Sound of footsteps walking on pavement"],
    ["Shopping Cart Rolling", "Sound of a shopping cart rolling in a supermarket"],
    ["Cash Register", "Sound of a cash register opening"],
    ["Fireworks", "Sound of fireworks exploding in the sky"],
    ["Coffee Machine", "Sound of a coffee machine brewing a fresh cup"],
    ["Elevator Arriving", "Sound of an elevator arriving with a ding"],
    ["Pencil Writing", "Sound of a pencil writing on paper"],
    ["Book Closing", "Sound of a book being closed"],
    ["Microwave Beeping", "Sound of a microwave beeping when cooking is done"],
    ["Guitar Strumming", "Sound of a guitar strumming a chord"]   
]

# %%
import re
def clean_filename(filename):
    # 알파벳, 숫자, 언더스코어, 하이픈만 허용하고 나머지는 언더스코어로 대체
    return re.sub(r'[^a-zA-Z0-9_-]', '_', filename)

# %%
import scipy.io.wavfile
import os

# 출력 디렉토리 경로
output_dir = "./data/train_noise"

# 디렉토리가 없으면 생성
os.makedirs(output_dir, exist_ok=True)

for i in range(5):
    for prompt_list in prompts:
        # 프롬프트에서 파일 이름 생성 (공백을 언더스코어로 대체)
        prompt = prompt_list[1]
        file_name = clean_filename(prompt.replace(" ", "_").lower())
        
        # 파일 이름에 반복 횟수 추가
        file_name = f"{file_name}_{i}.wav"
        
        # 전체 파일 경로 생성
        file_path = os.path.join(output_dir, file_name)
        
        # 오디오 생성
        audio = pipe(prompt, num_inference_steps=200, audio_length_in_s=5.0).audios[0]

        audio = librosa.resample(y=audio, orig_sr=16000, target_sr=32000)

        
        print(f"Saved: {file_path}")

        scipy.io.wavfile.write(file_path, rate=32000, data=audio)
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# Saved: ./data/train_noise/pig_grunting_while_searching_for_food_in_a_muddy_farmyard_0.wav
#   0%|          | 0/200 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 23
#      20 file_path = os.path.join(output_dir, file_name)
#      22 # 오디오 생성
# ---> 23 audio = pipe(prompt, num_inference_steps=200, audio_length_in_s=5.0).audios[0]
#      25 audio = librosa.resample(y=audio, orig_sr=16000, target_sr=32000)
#      28 print(f"Saved: {file_path}")
#
# File ~/.local/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# ...
